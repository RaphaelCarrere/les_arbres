# %%
import pandas as pd
import requests
import io

df_arbre = pd.read_csv("https://www.data.gouv.fr/api/1/datasets/r/60433484-f30e-44ef-a362-e5553a9b7a42", sep = ";")
df_arbre
# Out:
#         IDBASE TYPE EMPLACEMENT   DOMANIALITE   ARRONDISSEMENT  \
# 0       222651            Arbre    Alignement  PARIS 20E ARRDT
# 1       247888            Arbre    Alignement  PARIS 16E ARRDT
# 2       160993            Arbre     CIMETIERE     VAL-DE-MARNE
# 3       197686            Arbre  PERIPHERIQUE  PARIS 12E ARRDT
# 4       254349            Arbre    Alignement  PARIS 16E ARRDT
# ...        ...              ...           ...              ...
# 217483  108556            Arbre        Jardin  PARIS 16E ARRDT
# 217484  111432            Arbre        Jardin   PARIS 4E ARRDT
# 217485  114211            Arbre        Jardin  PARIS 19E ARRDT
# 217486  144178            Arbre     CIMETIERE   HAUTS-DE-SEINE
# 217487  146775            Arbre     CIMETIERE  PARIS 17E ARRDT
#
#        COMPLEMENT ADRESSE                                     LIEU / ADRESSE  \
# 0                    2-12                       PLACE DE L ADJUDANT VINCENOT
# ...
